# %% [markdown]
# ## Documentation
#
# To read more about the dense vector field type, visit the docs [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/dense-vector.html).
#
# ![dense_vector_field_type_docs](../images/dense_vector_field_type_docs.png)

# %% [markdown]
# ## Connect to ElasticSearch

# %%
from pprint import pprint
from elasticsearch import Elasticsearch

es = Elasticsearch('http://localhost:9200')
client_info = es.info()
print('Connected to Elasticsearch!')
pprint(client_info.body)
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'es-docker-cluster',
#  'cluster_uuid': '68vsKryIR7Ss49bLh7mz5Q',
#  'name': 'es01',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2025-12-16T10:09:08.849001802Z',
#              'build_flavor': 'default',
#              'build_hash': 'd8972a71dbbd64ff17f2f4dba9ca2c3fe09fb100',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '10.3.2',
#              'minimum_index_compatibility_version': '8.0.0',
#              'minimum_wire_compatibility_version': '8.19.0',
#              'number': '9.2.3'}}

# %% [markdown]
# ## Inserting documents

# %% [markdown]
# Because we are using the `dense_vector` data type, we need to do the mapping manually.

# %%
es.indices.delete(index='my_index', ignore_unavailable=True)
es.indices.create(
    index="my_index",
    mappings={
        "properties": {
            "sides_length": {
                "type": "dense_vector",
                "dims": 4
            },
            "shape": {
                "type": "keyword"
            }
        }
    },
)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %% [markdown]
# ### 1. Valid case

# %% [markdown]
# We specified that `sides_length` should be a vector with 4 values. Since this condition was met, the operation was executed successfully.

# %%
from pprint import pprint

response = es.index(
    index='my_index',
    id=1,
    document={
        "shape": "square",
        "sides_length": [5, 5, 5, 5],
    }
)

pprint(response.body)
# Out:
# {'_id': '1',
#  '_index': 'my_index',
#  '_primary_term': 1,
#  '_seq_no': 0,
#  '_shards': {'failed': 0, 'successful': 1, 'total': 2},
#  '_version': 1,
#  'result': 'created'}

# %% [markdown]
# Let's check the mapping. We can see that `sides_length` is a `dense_vector` with 4 dimensions and `cosine` set as the similarity measure. These are parameters we can modify if needed. Since we didn’t specify them when manually setting the mapping, Elasticsearch automatically applied the default values.

# %%
pprint(es.indices.get_mapping(index='my_index').body)
# Out:
# {'my_index': {'mappings': {'properties': {'shape': {'type': 'keyword'},
#                                           'sides_length': {'dims': 4,
#                                                            'index': True,
#                                                            'index_options': {'ef_construction': 100,
#                                                                              'm': 16,
#                                                                              'type': 'int8_hnsw'},
#                                                            'similarity': 'cosine',
#                                                            'type': 'dense_vector'}}}}}

# %% [markdown]
# ### 2. Invalid case

# %% [markdown]
# In this case, the operation fails because indexing a matrix is not supported with the `dense_vector` field type.

# %%
response = es.index(
    index='my_index',
    id=2,
    document={
        "shape": "square",
        "sides_length": [[5, 5], [5, 5]],
    }
)

pprint(response.body)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = es.index(
#       2     index='my_index',
#       3     id=2,
#       4     document={
#       5         "shape": "square",
#       6         "sides_length": [[5, 5], [5, 5]],
#       7     }
#       8 )
#      10 pprint(response.body)
#
# File ~/miniconda3/envs/elastic-search/lib/python3.11/site-packages/elasticsearch/_sync/client/utils.py:421, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     418         except KeyError:
#     419             pass
# --> 421 return api(*args, **kwargs)
#
# File ~/miniconda3/envs/elastic-search/lib/python3.11/site-packages/elasticsearch/_sync/client/__init__.py:2969, in Elasticsearch.index(self, index, document, body, id, error_trace, filter_path, human, if_primary_term, if_seq_no, include_source_on_error, op_type, pipeline, pretty, refresh, require_alias, require_data_stream, routing, timeout, version, version_type, wait_for_active_shards)
#    2967 __body = document if document is not None else body
#    2968 __headers = {"accept": "application/json", "content-type": "application/json"}
# -> 2969 return self.perform_request(  # type: ignore[return-value]
#    2970     __method,
#    2971     __path,
#    2972     params=__query,
#    2973     headers=__headers,
#    2974     body=__body,
#    2975     endpoint_id="index",
#    2976     path_parts=__path_parts,
#    2977 )
#
# File ~/miniconda3/envs/elastic-search/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)    264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File ~/miniconda3/envs/elastic-search/lib/python3.11/site-packages/elasticsearch/_sync/client/_base.py:351, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     348         except (ValueError, KeyError, TypeError):
#     349             pass
# --> 351     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     352         message=message, meta=meta, body=resp_body
#     353     )
#     355 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     356 if not self._verified_elasticsearch:
#     357     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'document_parsing_exception', 'Failed to parse object: expecting token of type [VALUE_NUMBER] but found [START_ARRAY]', Failed to parse object: expecting token of type [VALUE_NUMBER] but found [START_ARRAY])
